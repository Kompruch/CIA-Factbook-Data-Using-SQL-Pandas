# %% [markdown]
# # Analyzing CIA Factbook Data Using SQL

# %% [markdown]
# Here we will use sql to analyze data from `factbook.db`

# %% [markdown]
# ## Loading data

# %% [markdown]
# Here we use magic command `%%` (cell magic) and `%` (line magic) to run command, similar to run on terminal.

# %%
# %matplotlib notebook
# %config InlineBackend.figure_format = 'retina'

import pandas as pd
import matplotlib.pyplot as plt

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///factbook.db

# %% [markdown]
# ## Overview of the Data
# We'll begin by getting a sense of what the data looks like.

# %%
# %%sql
# SELECT *
#   FROM facts
#  LIMIT 5;
# Out:
#  * sqlite:///factbook.db
# Done.
# [(1, 'af', 'Afghanistan', 652230, 652230, 0, 32564342, 2.32, 38.57, 13.89, 1.51),
#  (2, 'al', 'Albania', 28748, 27398, 1350, 3029278, 0.3, 12.92, 6.58, 3.3),
#  (3, 'ag', 'Algeria', 2381741, 2381741, 0, 39542166, 1.84, 23.67, 4.31, 0.92),
#  (4, 'an', 'Andorra', 468, 468, 0, 85580, 0.12, 8.13, 6.96, 0.0),
#  (5, 'ao', 'Angola', 1246700, 1246700, 0, 19625353, 2.78, 38.78, 11.49, 0.46)]

# %% [markdown]
# Here are the descriptions for some of the columns:
#
# * name - The name of the country.
# * area - The total land and sea area of the country.
# * population - The country's population.
# * population_growth- The country's population growth as a percentage.
# * birth_rate - The country's birth rate, or the number of births a year per 1,000 people.
# * death_rate - The country's death rate, or the number of death a year per 1,000 people.
# * area- The country's total area (both land and water).
# * area_land - The country's land area in square kilometers.
# * area_water - The country's waterarea in square kilometers.
# Let's start by calculating some summary statistics and see what they tell us.

# %% [markdown]
# We can also use pandas

# %%
# %%sql fact <<
# SELECT * FROM facts;
# Out:
#  * sqlite:///factbook.db
# Done.
# Returning data to local variable fact

# %%
# code for single line
# fact = %sql SELECT * FROM facts

df = fact.DataFrame()
df.head()
# Out:
#    id code         name       area  area_land  area_water  population  \
# 0   1   af  Afghanistan   652230.0   652230.0         0.0  32564342.0
# 1   2   al      Albania    28748.0    27398.0      1350.0   3029278.0
# 2   3   ag      Algeria  2381741.0  2381741.0         0.0  39542166.0
# 3   4   an      Andorra      468.0      468.0         0.0     85580.0
# 4   5   ao       Angola  1246700.0  1246700.0         0.0  19625353.0
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               2.32       38.57       13.89            1.51
# 1               0.30       12.92        6.58            3.30
# 2               1.84       23.67        4.31            0.92
# 3               0.12        8.13        6.96            0.00
# 4               2.78       38.78       11.49            0.46

# %% [markdown]
# ## Summary Statistics

# %%
# %%sql
# SELECT MIN(population) AS min_pop,
#        MAX(population) AS max_pop,
#        MIN(population_growth) AS min_pop_growth,
#        MAX(population_growth) max_pop_growth
#   FROM facts;
# Out:
#  * sqlite:///factbook.db
# Done.
# [(0, 7256490011, 0.0, 4.02)]

# %% [markdown]
# A few things stick out from the summary statistics in the last screen:
#
# * There's a country with a population of 0
# * There's a country with a population of 7256490011 (or more than 7.2 billion people)
# Let's use subqueries to zoom in on just these countries without using the specific values.

# %% [markdown]
# We can also use pandas here as well

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 261 non-null    int64
#  1   code               261 non-null    object
#  2   name               261 non-null    object
#  3   area               249 non-null    float64
#  4   area_land          246 non-null    float64
#  5   area_water         243 non-null    float64
#  6   population         242 non-null    float64
#  7   population_growth  236 non-null    float64
#  8   birth_rate         228 non-null    float64
#  9   death_rate         228 non-null    float64
#  10  migration_rate     223 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 22.6+ KB
#               id          area     area_land     area_water    population  \
# count  261.00000  2.490000e+02  2.460000e+02     243.000000  2.420000e+02
# mean   131.00000  5.550935e+05  5.227026e+05   19067.592593  6.209493e+07
# std     75.48841  1.737041e+06  1.654027e+06   89559.192992  4.816938e+08
# min      1.00000  0.000000e+00  0.000000e+00       0.000000  0.000000e+00
# 25%     66.00000  7.600000e+02  7.532500e+02       0.000000  2.991022e+05
# 50%    131.00000  5.678500e+04  5.900950e+04     440.000000  5.219556e+06
# 75%    196.00000  3.420000e+05  3.259935e+05    6555.000000  1.873804e+07
# max    261.00000  1.709824e+07  1.637774e+07  891163.000000  7.256490e+09
#
#        population_growth  birth_rate  death_rate  migration_rate
# count         236.000000  228.000000  228.000000      223.000000
# mean            1.200975   19.328553    7.821272        3.433946
# std             0.901470    9.465795    2.878720        4.406689
# min             0.000000    6.650000    1.530000        0.000000
# 25%             0.427500   11.587500    5.917500        0.355000
# 50%             1.050000   16.555000    7.525000        1.910000
# 75%             1.875000   24.380000    9.435000        4.945000
# max             4.020000   45.450000   14.890000       22.390000

# %% [markdown]
# ## Exploring Outliers

# %%
# %%sql
# SELECT *
#   FROM facts
#  WHERE population == (SELECT MIN(population)
#                         FROM facts
#                      );
# Out:
#  * sqlite:///factbook.db
# Done.
# [(250, 'ay', 'Antarctica', None, 280000, None, 0, None, None, None, None)]

# %% [markdown]
# It seems like the table contains a row for Antarctica, which explains the population of 0.

# %%
# %%sql
# SELECT *
#   FROM facts
#  WHERE population == (SELECT MAX(population)
#                         FROM facts
#                      );
# Out:
#  * sqlite:///factbook.db
# Done.
# [(261, 'xx', 'World', None, None, None, 7256490011, 1.08, 18.6, 7.8, None)]

# %% [markdown]
# We also see that the table contains a row for the whole world, which explains the maximum population of over 7.2 billion we found earlier.
#
# Now that we know this, we should recalculate the summary statistics we calculated earlier, while excluding the row for the whole world.

# %% [markdown]
# ## Summary Statistics Revisited

# %%
# %%sql
# SELECT MIN(population) AS min_pop,
#        MAX(population) AS max_pop,
#        MIN(population_growth) AS min_pop_growth,
#        MAX(population_growth) AS max_pop_growth
#   FROM facts
#  WHERE name != 'World';
# Out:
#  * sqlite:///factbook.db
# Done.
# [(0, 1367485388, 0.0, 4.02)]

# %% [markdown]
# There's a country whose population closes in on 1.4 billion!

# %% [markdown]
# Below is how we perform the same task using pandas

# %%
df[df.name == 'World']
# Out:
#       id code   name  area  area_land  area_water    population  \
# 260  261   xx  World   NaN        NaN         NaN  7.256490e+09
#
#      population_growth  birth_rate  death_rate  migration_rate
# 260               1.08        18.6         7.8             NaN

# %%
clean_df = df.drop(260,axis=0)
clean_df[clean_df.name == 'World']
# Out:
# Empty DataFrame
# Columns: [id, code, name, area, area_land, area_water, population, population_growth, birth_rate, death_rate, migration_rate]
# Index: []

# %%
clean_df.describe()
# Out:
#                id          area     area_land     area_water    population  \
# count  260.000000  2.490000e+02  2.460000e+02     243.000000  2.410000e+02
# mean   130.500000  5.550935e+05  5.227026e+05   19067.592593  3.224267e+07
# std     75.199734  1.737041e+06  1.654027e+06   89559.192992  1.282067e+08
# min      1.000000  0.000000e+00  0.000000e+00       0.000000  0.000000e+00
# 25%     65.750000  7.600000e+02  7.532500e+02       0.000000  2.906040e+05
# 50%    130.500000  5.678500e+04  5.900950e+04     440.000000  5.207689e+06
# 75%    195.250000  3.420000e+05  3.259935e+05    6555.000000  1.815712e+07
# max    260.000000  1.709824e+07  1.637774e+07  891163.000000  1.367485e+09
#
#        population_growth  birth_rate  death_rate  migration_rate
# count         235.000000  227.000000  227.000000      223.000000
# mean            1.201489   19.331762    7.821366        3.433946
# std             0.903359    9.486590    2.885081        4.406689
# min             0.000000    6.650000    1.530000        0.000000
# 25%             0.425000   11.575000    5.905000        0.355000
# 50%             1.040000   16.470000    7.520000        1.910000
# 75%             1.880000   24.380000    9.440000        4.945000
# max             4.020000   45.450000   14.890000       22.390000

# %% [markdown]
# ## Exploring Average Population and Area
#
# Let's explore density. Density depends on the population and the country's area. Let's look at the average values for these two columns.
#
# We should take care of discarding the row for the whole planet.

# %%
# %%sql
# SELECT AVG(population) AS avg_population, AVG(area) AS avg_area
#   FROM facts
#  WHERE name != 'World';
# Out:
#  * sqlite:///factbook.db
# Done.
# [(32242666.56846473, 555093.546184739)]

# %% [markdown]
# We see that the average population is around 32 million and the average area is 555 thousand square kilometers.

# %% [markdown]
# ## Finding Densely Populated Countries

# %% [markdown]
# To finish, we'll build on the query above to find countries that are densely populated. We'll identify countries that have:
#
# * Above average values for population.
# * Below average values for area.

# %%
# %%sql
# SELECT *
#   FROM facts
#  WHERE population > (SELECT AVG(population)
#                        FROM facts
#                       WHERE name != 'World'
#                     )
#    AND area < (SELECT AVG(area)
#                  FROM facts
#                 WHERE name != 'World'
# );
# Out:
#  * sqlite:///factbook.db
# Done.
# [(14, 'bg', 'Bangladesh', 148460, 130170, 18290, 168957745, 1.6, 21.14, 5.61, 0.46),
#  (65, 'gm', 'Germany', 357022, 348672, 8350, 80854408, 0.17, 8.47, 11.42, 1.24),
#  (80, 'iz', 'Iraq', 438317, 437367, 950, 37056169, 2.93, 31.45, 3.77, 1.62),
#  (83, 'it', 'Italy', 301340, 294140, 7200, 61855120, 0.27, 8.74, 10.19, 4.1),
#  (85, 'ja', 'Japan', 377915, 364485, 13430, 126919659, 0.16, 7.93, 9.51, 0.0),
#  (91, 'ks', 'Korea, South', 99720, 96920, 2800, 49115196, 0.14, 8.19, 6.75, 0.0),
#  (120, 'mo', 'Morocco', 446550, 446300, 250, 33322699, 1.0, 18.2, 4.81, 3.36),
#  (138, 'rp', 'Philippines', 300000, 298170, 1830, 100998376, 1.61, 24.27, 6.11, 2.09),
#  (139, 'pl', 'Poland', 312685, 304255, 8430, 38562189, 0.09, 9.74, 10.19, 0.46),
#  (163, 'sp', 'Spain', 505370, 498980, 6390, 48146134, 0.89, 9.64, 9.04, 8.31),
#  (173, 'th', 'Thailand', 513120, 510890, 2230, 67976405, 0.34, 11.19, 7.8, 0.0),
#  (182, 'ug', 'Uganda', 241038, 197100, 43938, 37101745, 3.24, 43.79, 10.69, 0.74),
#  (185, 'uk', 'United Kingdom', 243610, 241930, 1680, 64088222, 0.54, 12.17, 9.35, 2.54),
#  (192, 'vm', 'Vietnam', 331210, 310070, 21140, 94348835, 0.97, 15.96, 5.93, 0.3)]

# %% [markdown]
# We can also perform the same task using pandas

# %%
df_dense = clean_df[(clean_df.population > clean_df.population.mean()) & (clean_df.area < clean_df.area.mean())]
df_dense.head(50)
# Out:
#       id code            name      area  area_land  area_water   population  \
# 13    14   bg      Bangladesh  148460.0   130170.0     18290.0  168957745.0
# 64    65   gm         Germany  357022.0   348672.0      8350.0   80854408.0
# 79    80   iz            Iraq  438317.0   437367.0       950.0   37056169.0
# 82    83   it           Italy  301340.0   294140.0      7200.0   61855120.0
# 84    85   ja           Japan  377915.0   364485.0     13430.0  126919659.0
# 90    91   ks    Korea, South   99720.0    96920.0      2800.0   49115196.0
# 119  120   mo         Morocco  446550.0   446300.0       250.0   33322699.0
# 137  138   rp     Philippines  300000.0   298170.0      1830.0  100998376.0
# 138  139   pl          Poland  312685.0   304255.0      8430.0   38562189.0
# 162  163   sp           Spain  505370.0   498980.0      6390.0   48146134.0
# 172  173   th        Thailand  513120.0   510890.0      2230.0   67976405.0
# 181  182   ug          Uganda  241038.0   197100.0     43938.0   37101745.0
# 184  185   uk  United Kingdom  243610.0   241930.0      1680.0   64088222.0
# 191  192   vm         Vietnam  331210.0   310070.0     21140.0   94348835.0
#
#      population_growth  birth_rate  death_rate  migration_rate
# 13                1.60       21.14        5.61            0.46
# 64                0.17        8.47       11.42            1.24
# 79                2.93       31.45        3.77            1.62
# 82                0.27        8.74       10.19            4.10
# 84                0.16        7.93        9.51            0.00
# 90                0.14        8.19        6.75            0.00
# 119               1.00       18.20        4.81            3.36
# 137               1.61       24.27        6.11            2.09
# 138               0.09        9.74       10.19            0.46
# 162               0.89        9.64        9.04            8.31
# 172               0.34       11.19        7.80            0.00
# 181               3.24       43.79       10.69            0.74
# 184               0.54       12.17        9.35            2.54
# 191               0.97       15.96        5.93            0.30

# %%
# %%sql top_pop <<
# SELECT *
#   FROM facts
#  WHERE name NOT IN ('World', 'European Union')
#  ORDER BY population DESC
#  LIMIT 10;
# Out:
#  * sqlite:///factbook.db
# Done.
# Returning data to local variable top_pop

# %%
df2 = top_pop.DataFrame().set_index('id')
df2.head()
# Out:
#     code           name     area  area_land  area_water  population  \
# id
# 37    ch          China  9596960    9326410      270550  1367485388
# 77    in          India  3287263    2973193      314070  1251695584
# 186   us  United States  9826675    9161966      664709   321368864
# 78    id      Indonesia  1904569    1811569       93000   255993674
# 24    br         Brazil  8515770    8358140      157630   204259812
#
#      population_growth  birth_rate  death_rate  migration_rate
# id
# 37                0.45       12.49        7.53            0.44
# 77                1.22       19.55        7.32            0.04
# 186               0.78       12.49        8.15            3.86
# 78                0.92       16.72        6.37            1.16
# 24                0.77       14.46        6.58            0.14

# %% [markdown]
# Here we can visualize our data using matplotlib

# %%
plt.pie(df2.population, labels=df2.name, autopct='%.2f%%')
plt.title('Portion of world top-10 highest population')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
